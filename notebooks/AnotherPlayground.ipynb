# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df
# Out:
#                G  budget policy  transmission_rate  transmission_known  \
# 0     montgomery     750   none               0.05               False
# 1     montgomery     750   none               0.05               False
# 2     montgomery     750   none               0.05               False
# 3     montgomery     750   none               0.05               False
# 4     montgomery     750   none               0.05               False
# ...          ...     ...    ...                ...                 ...
# 4345  montgomery     750   none               0.05               False
# 4346  montgomery     750   none               0.05               False
# 4347  montgomery     750   none               0.05               False
# 4348  montgomery     750   none               0.05               False
# 4349  montgomery     750   none               0.05               False
#
#       compliance_rate  compliance_known  partial_compliance  I_knowledge  \
# 0                   1             False               False            1
# 1                   1             False               False            1
# 2                   1             False               False            1
# 3                   1             False               False            1
# 4                   1             False               False            1
# ...               ...               ...                 ...          ...
# 4345                1             False               False            1
# 4346                1             False               False            1
# 4347                1             False               False            1
# 4348                1             False               False            1
# 4349                1             False               False            1
#
#       discovery_rate  snitch_rate from_cache            agent  trial_id  \
# 0               0.50          0.8    c7.json  DegGreedy2_fair         4
# 1               0.50          0.8    c7.json  DegGreedy2_fair         5
# 2               0.50          0.8    c7.json  DegGreedy2_fair         3
# 3               0.50          0.8    c7.json  DegGreedy2_fair         9
# 4               0.50          0.8    c7.json  DegGreedy2_fair        11
# ...              ...          ...        ...              ...       ...
# 4345            0.93          0.8    c7.json  DegGreedy2_fair        45
# 4346            0.93          0.8    c7.json  DegGreedy2_fair        43
# 4347            0.93          0.8    c7.json  DegGreedy2_fair        47
# 4348            0.93          0.8    c7.json  DegGreedy2_fair        48
# 4349            0.93          0.8    c7.json  DegGreedy2_fair        49
#
#       trial_id.1  infection_count  \
# 0              4            33615
# 1              5            33897
# 2              3            33451
# 3              9            33602
# 4             11            32969
# ...          ...              ...
# 4345          45            30837
# 4346          43            31501
# 4347          47            31339
# 4348          48            31582
# 4349          49            31973
#
#                                         infections_step
# 0     [0, 10, 7, 12, 20, 52, 80, 160, 269, 445, 460,...
# 1     [0, 10, 7, 12, 20, 52, 80, 160, 269, 430, 465,...
# 2     [0, 10, 7, 12, 20, 52, 80, 160, 269, 484, 542,...
# 3     [0, 10, 7, 12, 20, 52, 80, 160, 269, 476, 541,...
# 4     [0, 10, 7, 12, 20, 52, 80, 160, 269, 475, 541,...
# ...                                                 ...
# 4345  [0, 10, 7, 12, 20, 52, 80, 160, 269, 478, 482,...
# 4346  [0, 10, 7, 12, 20, 52, 80, 160, 269, 451, 489,...
# 4347  [0, 10, 7, 12, 20, 52, 80, 160, 269, 451, 488,...
# 4348  [0, 10, 7, 12, 20, 52, 80, 160, 269, 506, 485,...
# 4349  [0, 10, 7, 12, 20, 52, 80, 160, 269, 479, 510,...
#
# [4350 rows x 17 columns]

# %%
df = pd.read_csv("../output/run_BHatX/results.csv")

sns.lineplot(data=df, x='snitch_rate',y='infection_count',hue='agent')
# Out:
# <AxesSubplot:xlabel='snitch_rate', ylabel='infection_count'>

# %%
df = pd.read_csv("../output/run_LhbAZ/results.csv")

sns.lineplot(data=df, x='discovery_rate',y='infection_count',hue='agent')
# Out:
# <AxesSubplot:xlabel='discovery_rate', ylabel='infection_count'>
