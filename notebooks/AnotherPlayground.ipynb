# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../output/run_EJv4i/results.csv")

sns.lineplot(data=df, x='discovery_rate',y='infection_count',hue='agent')
# Out:
# <AxesSubplot:xlabel='discovery_rate', ylabel='infection_count'>

# %%
df = pd.read_csv("../output/run_dMfqS/results.csv")
df1 = pd.read_csv("../output/run_kWuFB/results.csv")

df = pd.concat([df,df1]).reset_index()

sns.lineplot(data=df, x='snitch_rate',y='infection_count',hue='agent')
# Out:
# <AxesSubplot:xlabel='snitch_rate', ylabel='infection_count'>
